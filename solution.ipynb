# %%
from temperatureEntry import plotar_temperaturas
from Dataset import Dataset

plotar_temperaturas(Dataset.SITKA_2021)

# Exemplo 2: Máximas e mínimas com sombra - Death Valley
plotar_temperaturas(Dataset.DEATH_VALLEY, show_low_temp=True)

# Exemplo 3: Máximas e mínimas - Sitka Julho
plotar_temperaturas(Dataset.SITKA_JULY, show_low_temp=True)
